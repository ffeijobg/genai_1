# %%
# installing necessary pacakges in my_env
# %pip install \
gradio==4.44.0 \
pydantic==2.10.6 \
ibm-watsonx-ai==1.1.2 \
langchain==0.2.11 \
langchain-community==0.2.10 \
langchain-ibm==0.1.11 \
huggingface_hub==0.23.0
# Out:
# Collecting gradio==4.44.0
#   Downloading gradio-4.44.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic==2.10.6
#   Downloading pydantic-2.10.6-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: ibm-watsonx-ai==1.1.2 in c:\users\office-server\appdata\roaming\python\python312\site-packages (1.1.2)
# Requirement already satisfied: langchain==0.2.11 in c:\users\office-server\appdata\roaming\python\python312\site-packages (0.2.11)
# Requirement already satisfied: langchain-community==0.2.10 in c:\users\office-server\appdata\roaming\python\python312\site-packages (0.2.10)
# Requirement already satisfied: langchain-ibm==0.1.11 in c:\users\office-server\appdata\roaming\python\python312\site-packages (0.1.11)
# Collecting huggingface_hub==0.23.0
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl.metadata (12 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.44.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (4.9.0)
# Requirement already satisfied: fastapi<1.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (0.124.2)
# Collecting ffmpy (from gradio==4.44.0)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.3.0 (from gradio==4.44.0)
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (0.28.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio==4.44.0)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (3.9.0)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (3.11.5)
# Requirement already satisfied: packaging in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (2.1.4)
# Collecting pillow<11.0,>=8.0 (from gradio==4.44.0)
#   Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# Collecting pydub (from gradio==4.44.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio==4.44.0)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio==4.44.0)
#   Downloading ruff-0.14.9-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting semantic-version~=2.0 (from gradio==4.44.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.44.0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (0.19.2)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from gradio==4.44.0) (4.14.1)
# Requirement already satisfied: urllib3~=2.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (2.3.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from gradio==4.44.0) (0.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from pydantic==2.10.6) (0.7.0)
# Collecting pydantic-core==2.27.2 (from pydantic==2.10.6)
#   Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in c:\users\office-server\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai==1.1.2) (2.32.2)
# Requirement already satisfied: certifi in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from ibm-watsonx-ai==1.1.2) (2025.10.5)
# Requirement already satisfied: lomond in c:\users\office-server\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai==1.1.2) (0.3.3)
# Requirement already satisfied: tabulate in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from ibm-watsonx-ai==1.1.2) (0.9.0)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: importlib-metadata in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from ibm-watsonx-ai==1.1.2) (8.7.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain==0.2.11) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from langchain==0.2.11) (3.13.2)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.23 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain==0.2.11) (0.2.43)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain==0.2.11) (0.2.4)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain==0.2.11) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain==0.2.11) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain-community==0.2.10) (0.6.7)
# Requirement already satisfied: filelock in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub==0.23.0) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub==0.23.0) (2025.7.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from huggingface_hub==0.23.0) (4.67.1)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.3.0->gradio==4.44.0)
#   Downloading websockets-12.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.11) (1.22.0)
# Requirement already satisfied: idna>=2.8 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio==4.44.0) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0,>=3.0->gradio==4.44.0) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (0.9.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from fastapi<1.0->gradio==4.44.0) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from fastapi<1.0->gradio==4.44.0) (0.0.4)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (2.9.0.post0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.23->langchain==0.2.11) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.2.11) (1.0.0)
# Requirement already satisfied: httpcore==1.* in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.24.1->gradio==4.44.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.44.0) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from matplotlib~=3.0->gradio==4.44.0) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.44.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0,>=1.0->gradio==4.44.0) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0->ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watsonx-ai==1.1.2) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from requests->ibm-watsonx-ai==1.1.2) (3.4.2)
# Requirement already satisfied: greenlet>=1 in c:\users\office-server\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.11) (3.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (8.2.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0,>=0.12->gradio==4.44.0) (14.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.10) (1.1.0)
# Requirement already satisfied: colorama in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio==4.44.0) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==4.44.0) (0.1.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\office-server\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata->ibm-watsonx-ai==1.1.2) (3.23.0)
# Downloading gradio-4.44.0-py3-none-any.whl (18.1 MB)
#    ---------------------------------------- 0.0/18.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/18.1 MB 7.5 MB/s eta 0:00:03
#    -------- ------------------------------- 3.9/18.1 MB 10.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.9/18.1 MB 13.2 MB/s eta 0:00:01
#    --------------------------- ------------ 12.6/18.1 MB 16.1 MB/s eta 0:00:01
#    ------------------------------------ --- 16.5/18.1 MB 16.5 MB/s eta 0:00:01
#    ---------------------------------------- 18.1/18.1 MB 16.8 MB/s  0:00:01
# Downloading pydantic-2.10.6-py3-none-any.whl (431 kB)
# Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Downloading pydantic_core-2.27.2-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 27.4 MB/s  0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 29.4 MB/s  0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading websockets-12.0-cp312-cp312-win_amd64.whl (124 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading ruff-0.14.9-py3-none-win_amd64.whl (14.7 MB)
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    ---------------- ----------------------- 6.0/14.7 MB 30.7 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.7 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.7/14.7 MB 33.0 MB/s  0:00:00
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub, websockets, tomlkit, semantic-version, ruff, python-multipart, pydantic-core, pillow, markupsafe, ffmpy, aiofiles, pydantic, huggingface_hub, gradio-client, gradio
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 15.0.1
#
#     Uninstalling websockets-15.0.1:
#
#       Successfully uninstalled websockets-15.0.1
#
#    -- -------------------------------------  1/15 [websockets]
#    -- -------------------------------------  1/15 [websockets]
#   Attempting uninstall: tomlkit
#    -- -------------------------------------  1/15 [websockets]
#     Found existing installation: tomlkit 0.13.3
#    -- -------------------------------------  1/15 [websockets]
#     Uninstalling tomlkit-0.13.3:
#    -- -------------------------------------  1/15 [websockets]
#       Successfully uninstalled tomlkit-0.13.3
#    -- -------------------------------------  1/15 [websockets]
#    -------- -------------------------------  3/15 [semantic-version]
#    ------------- --------------------------  5/15 [python-multipart]
#   Attempting uninstall: pydantic-core
#    ------------- --------------------------  5/15 [python-multipart]
#     Found existing installation: pydantic_core 2.33.2
#    ------------- --------------------------  5/15 [python-multipart]
#     Uninstalling pydantic_core-2.33.2:
#    ------------- --------------------------  5/15 [python-multipart]
#       Successfully uninstalled pydantic_core-2.33.2
#    ------------- --------------------------  5/15 [python-multipart]
#   Attempting uninstall: pillow
#    ------------- --------------------------  5/15 [python-multipart]
#     Found existing installation: pillow 11.1.0
#    ------------- --------------------------  5/15 [python-multipart]
#     Uninstalling pillow-11.1.0:
#    ------------- --------------------------  5/15 [python-multipart]
#       Successfully uninstalled pillow-11.1.0
#    ------------- --------------------------  5/15 [python-multipart]
#    ------------------ ---------------------  7/15 [pillow]
#    ------------------ ---------------------  7/15 [pillow]
#    ------------------ ---------------------  7/15 [pillow]
#    ------------------ ---------------------  7/15 [pillow]
#   Attempting uninstall: markupsafe
#    ------------------ ---------------------  7/15 [pillow]
#     Found existing installation: MarkupSafe 3.0.2
#    ------------------ ---------------------  7/15 [pillow]
#    --------------------- ------------------  8/15 [markupsafe]
#     Uninstalling MarkupSafe-3.0.2:
#    --------------------- ------------------  8/15 [markupsafe]
#       Successfully uninstalled MarkupSafe-3.0.2
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#    --------------------- ------------------  8/15 [markupsafe]
#   Attempting uninstall: aiofiles
#    --------------------- ------------------  8/15 [markupsafe]
#     Found existing installation: aiofiles 25.1.0
#    --------------------- ------------------  8/15 [markupsafe]
#     Uninstalling aiofiles-25.1.0:
#    --------------------- ------------------  8/15 [markupsafe]
#       Successfully uninstalled aiofiles-25.1.0
#    --------------------- ------------------  8/15 [markupsafe]
#    -------------------------- ------------- 10/15 [aiofiles]
#   Attempting uninstall: pydantic
#    -------------------------- ------------- 10/15 [aiofiles]
#     Found existing installation: pydantic 1.10.13
#    -------------------------- ------------- 10/15 [aiofiles]
#     Uninstalling pydantic-1.10.13:
#    -------------------------- ------------- 10/15 [aiofiles]
#       Successfully uninstalled pydantic-1.10.13
#    -------------------------- ------------- 10/15 [aiofiles]
#    ----------------------------- ---------- 11/15 [pydantic]
#    ----------------------------- ---------- 11/15 [pydantic]
#    ----------------------------- ---------- 11/15 [pydantic]
#    ----------------------------- ---------- 11/15 [pydantic]
#    ----------------------------- ---------- 11/15 [pydantic]
#   Attempting uninstall: huggingface_hub
#    ----------------------------- ---------- 11/15 [pydantic]
#     Found existing installation: huggingface-hub 0.36.0
#    ----------------------------- ---------- 11/15 [pydantic]
#     Uninstalling huggingface-hub-0.36.0:
#    ----------------------------- ---------- 11/15 [pydantic]
#       Successfully uninstalled huggingface-hub-0.36.0
#    ----------------------------- ---------- 11/15 [pydantic]
#    -------------------------------- ------- 12/15 [huggingface_hub]
#    -------------------------------- ------- 12/15 [huggingface_hub]
#    -------------------------------- ------- 12/15 [huggingface_hub]
#    -------------------------------- ------- 12/15 [huggingface_hub]
#    ---------------------------------- ----- 13/15 [gradio-client]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ------------------------------------- -- 14/15 [gradio]
#    ---------------------------------------- 15/15 [gradio]
#
# Successfully installed aiofiles-23.2.1 ffmpy-1.0.0 gradio-4.44.0 gradio-client-1.3.0 huggingface_hub-0.23.0 markupsafe-2.1.5 pillow-10.4.0 pydantic-2.10.6 pydantic-core-2.27.2 pydub-0.25.1 python-multipart-0.0.20 ruff-0.14.9 semantic-version-2.10.0 tomlkit-0.12.0 websockets-12.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\OFFICE-SERVER\AppData\Local\Programs\Python\Python312\Lib\site-packages\~arkupsafe'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.57.3 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 0.23.0 which is incompatible.
# unstructured-client 0.42.4 requires aiofiles>=24.1.0, but you have aiofiles 23.2.1 which is incompatible.
# unstructured-client 0.42.4 requires pydantic>=2.11.2, but you have pydantic 2.10.6 which is incompatible.
# unstructured-client 0.42.4 requires pypdf>=6.2.0, but you have pypdf 4.3.1 which is incompatible.
# datasets 4.4.1 requires huggingface-hub<2.0,>=0.25.0, but you have huggingface-hub 0.23.0 which is incompatible.
# langchain-classic 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.2.43 which is incompatible.
# langchain-classic 1.0.0 requires langchain-text-splitters<2.0.0,>=1.0.0, but you have langchain-text-splitters 0.2.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gradio as gr
from huggingface_hub import HfFolder

def add_numbers(Num1, Num2):
    return Num1 + Num2

# Define the interface
demo = gr.Interface(
    fn=add_numbers, 
    inputs=[gr.Number(), gr.Number()], # Create two numerical input fields where users can enter numbers
    outputs=gr.Number() # Create numerical output fields
)

# Launch the interface
demo.launch(server_name="127.0.0.1", server_port= 7860)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# C:\Users\OFFICE-SERVER\AppData\Local\Programs\Python\Python312\Lib\site-packages\gradio\analytics.py:106: UserWarning: IMPORTANT: You are using gradio version 4.44.0, however version 4.44.1 is available, please upgrade.
# --------
#   warnings.warn(
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
